# %%
# %matplotlib inline

# %% [markdown]
# # Primes
#
# I had been Solving a Project Euler problem https://projecteuler.net/problem=49 (details to be given later). During that project I was looking at the 'deltas' between primes and their relationships. I started thinking about primes and wondered how that delta shifted over time as well as the density of primes changes as n increases. Let's plot the number of primes per a unit. In this case I choose 1000.

# %% [markdown]
# Here's a small program running that shows how many primes in any interval of 1000, up to 10,0000. At the end I show a small graph using matplotlib and the code you can run to do the same.

# %%
# %run num_primes3.py
# Out:
# There are 168 primes from 1 to 1000
# There are 135 primes from 1001 to 2000
# There are 127 primes from 2001 to 3000
# There are 120 primes from 3001 to 4000
# There are 119 primes from 4001 to 5000
# There are 114 primes from 5001 to 6000
# There are 117 primes from 6001 to 7000
# There are 107 primes from 7001 to 8000
# There are 110 primes from 8001 to 9000
# There are 112 primes from 9001 to 10000
# There are 1229 primes up to 10000

# %% [markdown]
# We started at 168 and continue to drop to 112 by the time we get to 10,000.

# %% [markdown]
# Pretty Neat.

# %% [markdown]
# Well, lets kick it up a notch. Let go to 100,000. (It's one louder). LOL

# %%
# %run num_primes3.py
# Out:
# There are 168 primes from 1 to 1000
# There are 135 primes from 1001 to 2000
# There are 127 primes from 2001 to 3000
# There are 120 primes from 3001 to 4000
# There are 119 primes from 4001 to 5000
# There are 114 primes from 5001 to 6000
# There are 117 primes from 6001 to 7000
# There are 107 primes from 7001 to 8000
# There are 110 primes from 8001 to 9000
# There are 112 primes from 9001 to 10000
# There are 106 primes from 10001 to 11000
# There are 103 primes from 11001 to 12000
# There are 109 primes from 12001 to 13000
# There are 105 primes from 13001 to 14000
# There are 102 primes from 14001 to 15000
# There are 108 primes from 15001 to 16000
# There are 98 primes from 16001 to 17000
# There are 104 primes from 17001 to 18000
# There are 94 primes from 18001 to 19000
# There are 104 primes from 19001 to 20000
# There are 98 primes from 20001 to 21000
# There are 104 primes from 21001 to 22000
# There are 100 primes from 22001 to 23000
# There are 104 primes from 23001 to 24000
# There are 94 primes from 24001 to 25000
# There are 98 primes from 25001 to 26000
# There are 101 primes from 26001 to 27000
# There are 94 primes from 27001 to 28000
# There are 98 primes from 28001 to 29000
# There are 92 primes from 29001 to 30000
# There are 95 primes from 30001 to 31000
# There are 92 primes from 31001 to 32000
# There are 106 primes from 32001 to 33000
# There are 100 primes from 33001 to 34000
# There are 94 primes from 34001 to 35000
# There are 92 primes from 35001 to 36000
# There are 99 primes from 36001 to 37000
# There are 94 primes from 37001 to 38000
# There are 90 primes from 38001 to 39000
# There are 96 primes from 39001 to 40000
# There are 88 primes from 40001 to 41000
# There are 101 primes from 41001 to 42000
# There are 102 primes from 42001 to 43000
# There are 85 primes from 43001 to 44000
# There are 96 primes from 44001 to 45000
# There are 86 primes from 45001 to 46000
# There are 90 primes from 46001 to 47000
# There are 95 primes from 47001 to 48000
# There are 89 primes from 48001 to 49000
# There are 98 primes from 49001 to 50000
# There are 89 primes from 50001 to 51000
# There are 97 primes from 51001 to 52000
# There are 89 primes from 52001 to 53000
# There are 92 primes from 53001 to 54000
# There are 90 primes from 54001 to 55000
# There are 93 primes from 55001 to 56000
# There are 99 primes from 56001 to 57000
# There are 91 primes from 57001 to 58000
# There are 90 primes from 58001 to 59000
# There are 94 primes from 59001 to 60000
# There are 88 primes from 60001 to 61000
# There are 87 primes from 61001 to 62000
# There are 88 primes from 62001 to 63000
# There are 93 primes from 63001 to 64000
# There are 80 primes from 64001 to 65000
# There are 98 primes from 65001 to 66000
# There are 84 primes from 66001 to 67000
# There are 99 primes from 67001 to 68000
# There are 80 primes from 68001 to 69000
# There are 81 primes from 69001 to 70000
# There are 98 primes from 70001 to 71000
# There are 95 primes from 71001 to 72000
# There are 90 primes from 72001 to 73000
# There are 83 primes from 73001 to 74000
# There are 92 primes from 74001 to 75000
# There are 91 primes from 75001 to 76000
# There are 83 primes from 76001 to 77000
# There are 95 primes from 77001 to 78000
# There are 84 primes from 78001 to 79000
# There are 91 primes from 79001 to 80000
# There are 88 primes from 80001 to 81000
# There are 92 primes from 81001 to 82000
# There are 89 primes from 82001 to 83000
# There are 84 primes from 83001 to 84000
# There are 87 primes from 84001 to 85000
# There are 85 primes from 85001 to 86000
# There are 88 primes from 86001 to 87000
# There are 93 primes from 87001 to 88000
# There are 76 primes from 88001 to 89000
# There are 94 primes from 89001 to 90000
# There are 89 primes from 90001 to 91000
# There are 85 primes from 91001 to 92000
# There are 97 primes from 92001 to 93000
# There are 86 primes from 93001 to 94000
# There are 87 primes from 94001 to 95000
# There are 95 primes from 95001 to 96000
# There are 84 primes from 96001 to 97000
# There are 82 primes from 97001 to 98000
# There are 87 primes from 98001 to 99000
# There are 87 primes from 99001 to 100000
# The lowest number of primes from 1 to 100000 is 76
# There are 9592 primes up to 100000

# %% [markdown]
# The number of primes per thousand is steadying and slowly decreasing, but it is bouncy at times.
#
# There are a few outliers as you can see in the chart. I am particularly curious about 88001 to 89000. Somehow there's only 76 primes in that stretch. Visually it jumps right out at you.

# %% [markdown]
# After 100,000 I've put in a few print statement to catch the lowest number of primes.

# %% [markdown]
# If we crank it up yet another few notches, let see how we do to 5 million.

# %%
# %run num_primes3.py
# Out:
# There are 168 primes from 1 to 1000
# There are 135 primes from 1001 to 2000
# There are 127 primes from 2001 to 3000
# There are 120 primes from 3001 to 4000
# There are 119 primes from 4001 to 5000
# There are 114 primes from 5001 to 6000
# There are 117 primes from 6001 to 7000
# There are 107 primes from 7001 to 8000
# There are 110 primes from 8001 to 9000
# There are 112 primes from 9001 to 10000
# There are 106 primes from 10001 to 11000
# There are 103 primes from 11001 to 12000
# There are 109 primes from 12001 to 13000
# There are 105 primes from 13001 to 14000
# There are 102 primes from 14001 to 15000
# There are 108 primes from 15001 to 16000
# There are 98 primes from 16001 to 17000
# There are 104 primes from 17001 to 18000
# There are 94 primes from 18001 to 19000
# There are 104 primes from 19001 to 20000
# There are 98 primes from 20001 to 21000
# There are 104 primes from 21001 to 22000
# There are 100 primes from 22001 to 23000
# There are 104 primes from 23001 to 24000
# There are 94 primes from 24001 to 25000
# There are 98 primes from 25001 to 26000
# There are 101 primes from 26001 to 27000
# There are 94 primes from 27001 to 28000
# There are 98 primes from 28001 to 29000
# There are 92 primes from 29001 to 30000
# There are 95 primes from 30001 to 31000
# There are 92 primes from 31001 to 32000
# There are 106 primes from 32001 to 33000
# There are 100 primes from 33001 to 34000
# There are 94 primes from 34001 to 35000
# There are 92 primes from 35001 to 36000
# There are 99 primes from 36001 to 37000
# There are 94 primes from 37001 to 38000
# There are 90 primes from 38001 to 39000
# There are 96 primes from 39001 to 40000
# There are 88 primes from 40001 to 41000
# There are 101 primes from 41001 to 42000
# There are 102 primes from 42001 to 43000
# There are 85 primes from 43001 to 44000
# There are 96 primes from 44001 to 45000
# There are 86 primes from 45001 to 46000
# There are 90 primes from 46001 to 47000
# There are 95 primes from 47001 to 48000
# There are 89 primes from 48001 to 49000
# There are 98 primes from 49001 to 50000
# There are 89 primes from 50001 to 51000
# There are 97 primes from 51001 to 52000
# There are 89 primes from 52001 to 53000
# There are 92 primes from 53001 to 54000
# There are 90 primes from 54001 to 55000
# There are 93 primes from 55001 to 56000
# There are 99 primes from 56001 to 57000
# There are 91 primes from 57001 to 58000
# There are 90 primes from 58001 to 59000
# There are 94 primes from 59001 to 60000
# There are 88 primes from 60001 to 61000
# There are 87 primes from 61001 to 62000
# There are 88 primes from 62001 to 63000
# There are 93 primes from 63001 to 64000
# There are 80 primes from 64001 to 65000
# There are 98 primes from 65001 to 66000
# There are 84 primes from 66001 to 67000
# There are 99 primes from 67001 to 68000
# There are 80 primes from 68001 to 69000
# There are 81 primes from 69001 to 70000
# There are 98 primes from 70001 to 71000
# There are 95 primes from 71001 to 72000
# There are 90 primes from 72001 to 73000
# There are 83 primes from 73001 to 74000
# There are 92 primes from 74001 to 75000
# There are 91 primes from 75001 to 76000
# There are 83 primes from 76001 to 77000
# There are 95 primes from 77001 to 78000
# There are 84 primes from 78001 to 79000
# There are 91 primes from 79001 to 80000
# There are 88 primes from 80001 to 81000
# There are 92 primes from 81001 to 82000
# There are 89 primes from 82001 to 83000
# There are 84 primes from 83001 to 84000
# There are 87 primes from 84001 to 85000
# There are 85 primes from 85001 to 86000
# There are 88 primes from 86001 to 87000
# There are 93 primes from 87001 to 88000
# There are 76 primes from 88001 to 89000
# There are 94 primes from 89001 to 90000
# There are 89 primes from 90001 to 91000
# There are 85 primes from 91001 to 92000
# There are 97 primes from 92001 to 93000
# There are 86 primes from 93001 to 94000
# There are 87 primes from 94001 to 95000
# There are 95 primes from 95001 to 96000
# There are 84 primes from 96001 to 97000
# There are 82 primes from 97001 to 98000
# There are 87 primes from 98001 to 99000
# There are 87 primes from 99001 to 100000
# The lowest number of primes from 1 to 5000000 is 76
# There are 81 primes from 100001 to 101000
# There are 93 primes from 101001 to 102000
# There are 87 primes from 102001 to 103000
# There are 80 primes from 103001 to 104000
# There are 91 primes from 104001 to 105000
# There are 82 primes from 105001 to 106000
# There are 92 primes from 106001 to 107000
# There are 76 primes from 107001 to 108000
# There are 91 primes from 108001 to 109000
# There are 88 primes from 109001 to 110000
# There are 83 primes from 110001 to 111000
# There are 84 primes from 111001 to 112000
# There are 81 primes from 112001 to 113000
# There are 88 primes from 113001 to 114000
# There are 82 primes from 114001 to 115000
# There are 93 primes from 115001 to 116000
# There are 81 primes from 116001 to 117000
# There are 90 primes from 117001 to 118000
# There are 79 primes from 118001 to 119000
# There are 87 primes from 119001 to 120000
# There are 88 primes from 120001 to 121000
# There are 86 primes from 121001 to 122000
# There are 88 primes from 122001 to 123000
# There are 88 primes from 123001 to 124000
# There are 83 primes from 124001 to 125000
# There are 84 primes from 125001 to 126000
# There are 83 primes from 126001 to 127000
# There are 86 primes from 127001 to 128000
# There are 89 primes from 128001 to 129000
# There are 83 primes from 129001 to 130000
# There are 85 primes from 130001 to 131000
# There are 83 primes from 131001 to 132000
# There are 87 primes from 132001 to 133000
# There are 82 primes from 133001 to 134000
# There are 80 primes from 134001 to 135000
# There are 89 primes from 135001 to 136000
# There are 96 primes from 136001 to 137000
# There are 80 primes from 137001 to 138000
# There are 85 primes from 138001 to 139000
# There are 84 primes from 139001 to 140000
# There are 87 primes from 140001 to 141000
# There are 87 primes from 141001 to 142000
# There are 82 primes from 142001 to 143000
# There are 77 primes from 143001 to 144000
# There are 79 primes from 144001 to 145000
# There are 85 primes from 145001 to 146000
# There are 84 primes from 146001 to 147000
# There are 83 primes from 147001 to 148000
# There are 83 primes from 148001 to 149000
# There are 91 primes from 149001 to 150000
# There are 85 primes from 150001 to 151000
# There are 90 primes from 151001 to 152000
# There are 88 primes from 152001 to 153000
# There are 77 primes from 153001 to 154000
# There are 84 primes from 154001 to 155000
# There are 85 primes from 155001 to 156000
# There are 76 primes from 156001 to 157000
# There are 88 primes from 157001 to 158000
# There are 77 primes from 158001 to 159000
# There are 85 primes from 159001 to 160000
# There are 85 primes from 160001 to 161000
# There are 84 primes from 161001 to 162000
# There are 81 primes from 162001 to 163000
# There are 83 primes from 163001 to 164000
# There are 77 primes from 164001 to 165000
# There are 80 primes from 165001 to 166000
# There are 81 primes from 166001 to 167000
# There are 83 primes from 167001 to 168000
# There are 73 primes from 168001 to 169000
# There are 87 primes from 169001 to 170000
# There are 87 primes from 170001 to 171000
# There are 81 primes from 171001 to 172000
# There are 89 primes from 172001 to 173000
# There are 79 primes from 173001 to 174000
# There are 83 primes from 174001 to 175000
# There are 75 primes from 175001 to 176000
# There are 95 primes from 176001 to 177000
# There are 73 primes from 177001 to 178000
# There are 89 primes from 178001 to 179000
# There are 94 primes from 179001 to 180000
# There are 71 primes from 180001 to 181000
# There are 79 primes from 181001 to 182000
# There are 91 primes from 182001 to 183000
# There are 79 primes from 183001 to 184000
# There are 83 primes from 184001 to 185000
# There are 91 primes from 185001 to 186000
# There are 79 primes from 186001 to 187000
# There are 87 primes from 187001 to 188000
# There are 80 primes from 188001 to 189000
# There are 88 primes from 189001 to 190000
# There are 75 primes from 190001 to 191000
# There are 81 primes from 191001 to 192000
# There are 89 primes from 192001 to 193000
# There are 84 primes from 193001 to 194000
# There are 74 primes from 194001 to 195000
# There are 85 primes from 195001 to 196000
# There are 76 primes from 196001 to 197000
# There are 87 primes from 197001 to 198000
# There are 86 primes from 198001 to 199000
# There are 77 primes from 199001 to 200000
# The lowest number of primes from 1 to 5000000 is 71
# There are 77 primes from 200001 to 201000
# There are 87 primes from 201001 to 202000
# There are 78 primes from 202001 to 203000
# There are 78 primes from 203001 to 204000
# There are 77 primes from 204001 to 205000
# There are 83 primes from 205001 to 206000
# There are 83 primes from 206001 to 207000
# There are 87 primes from 207001 to 208000
# There are 85 primes from 208001 to 209000
# There are 88 primes from 209001 to 210000
# There are 84 primes from 210001 to 211000
# There are 86 primes from 211001 to 212000
# There are 69 primes from 212001 to 213000
# There are 81 primes from 213001 to 214000
# There are 86 primes from 214001 to 215000
# There are 74 primes from 215001 to 216000
# There are 76 primes from 216001 to 217000
# There are 80 primes from 217001 to 218000
# There are 84 primes from 218001 to 219000
# There are 91 primes from 219001 to 220000
# There are 78 primes from 220001 to 221000
# There are 80 primes from 221001 to 222000
# There are 81 primes from 222001 to 223000
# There are 80 primes from 223001 to 224000
# There are 83 primes from 224001 to 225000
# There are 84 primes from 225001 to 226000
# There are 76 primes from 226001 to 227000
# There are 80 primes from 227001 to 228000
# There are 89 primes from 228001 to 229000
# There are 88 primes from 229001 to 230000
# There are 84 primes from 230001 to 231000
# There are 78 primes from 231001 to 232000
# There are 76 primes from 232001 to 233000
# There are 71 primes from 233001 to 234000
# There are 87 primes from 234001 to 235000
# There are 73 primes from 235001 to 236000
# There are 76 primes from 236001 to 237000
# There are 73 primes from 237001 to 238000
# There are 87 primes from 238001 to 239000
# There are 79 primes from 239001 to 240000
# There are 80 primes from 240001 to 241000
# There are 91 primes from 241001 to 242000
# There are 76 primes from 242001 to 243000
# There are 77 primes from 243001 to 244000
# There are 88 primes from 244001 to 245000
# There are 80 primes from 245001 to 246000
# There are 84 primes from 246001 to 247000
# There are 79 primes from 247001 to 248000
# There are 88 primes from 248001 to 249000
# There are 80 primes from 249001 to 250000
# There are 71 primes from 250001 to 251000
# There are 88 primes from 251001 to 252000
# There are 78 primes from 252001 to 253000
# There are 81 primes from 253001 to 254000
# There are 76 primes from 254001 to 255000
# There are 87 primes from 255001 to 256000
# There are 72 primes from 256001 to 257000
# There are 78 primes from 257001 to 258000
# There are 86 primes from 258001 to 259000
# There are 76 primes from 259001 to 260000
# There are 77 primes from 260001 to 261000
# There are 73 primes from 261001 to 262000
# There are 79 primes from 262001 to 263000
# There are 84 primes from 263001 to 264000
# There are 80 primes from 264001 to 265000
# There are 78 primes from 265001 to 266000
# There are 87 primes from 266001 to 267000
# There are 94 primes from 267001 to 268000
# There are 75 primes from 268001 to 269000
# There are 78 primes from 269001 to 270000
# There are 84 primes from 270001 to 271000
# There are 78 primes from 271001 to 272000
# There are 83 primes from 272001 to 273000
# There are 71 primes from 273001 to 274000
# There are 80 primes from 274001 to 275000
# There are 83 primes from 275001 to 276000
# There are 83 primes from 276001 to 277000
# There are 74 primes from 277001 to 278000
# There are 81 primes from 278001 to 279000
# There are 73 primes from 279001 to 280000
# There are 87 primes from 280001 to 281000
# There are 85 primes from 281001 to 282000
# There are 77 primes from 282001 to 283000
# There are 72 primes from 283001 to 284000
# There are 90 primes from 284001 to 285000
# There are 77 primes from 285001 to 286000
# There are 71 primes from 286001 to 287000
# There are 71 primes from 287001 to 288000
# There are 77 primes from 288001 to 289000
# There are 85 primes from 289001 to 290000
# There are 84 primes from 290001 to 291000
# There are 77 primes from 291001 to 292000
# There are 78 primes from 292001 to 293000
# There are 68 primes from 293001 to 294000
# There are 85 primes from 294001 to 295000
# There are 75 primes from 295001 to 296000
# There are 82 primes from 296001 to 297000
# There are 73 primes from 297001 to 298000
# There are 73 primes from 298001 to 299000
# There are 78 primes from 299001 to 300000
# The lowest number of primes from 1 to 5000000 is 68
# There are 85 primes from 300001 to 301000
# There are 83 primes from 301001 to 302000
# There are 72 primes from 302001 to 303000
# There are 84 primes from 303001 to 304000
# There are 88 primes from 304001 to 305000
# There are 80 primes from 305001 to 306000
# There are 82 primes from 306001 to 307000
# There are 73 primes from 307001 to 308000
# There are 76 primes from 308001 to 309000
# There are 80 primes from 309001 to 310000
# There are 79 primes from 310001 to 311000
# There are 69 primes from 311001 to 312000
# There are 86 primes from 312001 to 313000
# There are 86 primes from 313001 to 314000
# There are 76 primes from 314001 to 315000
# There are 77 primes from 315001 to 316000
# There are 84 primes from 316001 to 317000
# There are 84 primes from 317001 to 318000
# There are 81 primes from 318001 to 319000
# There are 86 primes from 319001 to 320000
# There are 79 primes from 320001 to 321000
# There are 80 primes from 321001 to 322000
# There are 81 primes from 322001 to 323000
# There are 71 primes from 323001 to 324000
# There are 87 primes from 324001 to 325000
# There are 85 primes from 325001 to 326000
# There are 73 primes from 326001 to 327000
# There are 86 primes from 327001 to 328000
# There are 73 primes from 328001 to 329000
# There are 81 primes from 329001 to 330000
# There are 80 primes from 330001 to 331000
# There are 82 primes from 331001 to 332000
# There are 72 primes from 332001 to 333000
# There are 81 primes from 333001 to 334000
# There are 77 primes from 334001 to 335000
# There are 77 primes from 335001 to 336000
# There are 84 primes from 336001 to 337000
# There are 80 primes from 337001 to 338000
# There are 77 primes from 338001 to 339000
# There are 68 primes from 339001 to 340000
# There are 84 primes from 340001 to 341000
# There are 77 primes from 341001 to 342000
# There are 77 primes from 342001 to 343000
# There are 80 primes from 343001 to 344000
# There are 80 primes from 344001 to 345000
# There are 76 primes from 345001 to 346000
# There are 80 primes from 346001 to 347000
# There are 82 primes from 347001 to 348000
# There are 77 primes from 348001 to 349000
# There are 82 primes from 349001 to 350000
# There are 74 primes from 350001 to 351000
# There are 81 primes from 351001 to 352000
# There are 82 primes from 352001 to 353000
# There are 76 primes from 353001 to 354000
# There are 87 primes from 354001 to 355000
# There are 79 primes from 355001 to 356000
# There are 67 primes from 356001 to 357000
# There are 80 primes from 357001 to 358000
# There are 83 primes from 358001 to 359000
# There are 71 primes from 359001 to 360000
# There are 68 primes from 360001 to 361000
# There are 79 primes from 361001 to 362000
# There are 76 primes from 362001 to 363000
# There are 84 primes from 363001 to 364000
# There are 77 primes from 364001 to 365000
# There are 77 primes from 365001 to 366000
# There are 85 primes from 366001 to 367000
# There are 79 primes from 367001 to 368000
# There are 72 primes from 368001 to 369000
# There are 68 primes from 369001 to 370000
# There are 70 primes from 370001 to 371000
# There are 76 primes from 371001 to 372000
# There are 81 primes from 372001 to 373000
# There are 73 primes from 373001 to 374000
# There are 82 primes from 374001 to 375000
# There are 85 primes from 375001 to 376000
# There are 80 primes from 376001 to 377000
# There are 71 primes from 377001 to 378000
# There are 77 primes from 378001 to 379000
# There are 83 primes from 379001 to 380000
# There are 72 primes from 380001 to 381000
# There are 76 primes from 381001 to 382000
# There are 74 primes from 382001 to 383000
# There are 81 primes from 383001 to 384000
# There are 78 primes from 384001 to 385000
# There are 80 primes from 385001 to 386000
# There are 78 primes from 386001 to 387000
# There are 69 primes from 387001 to 388000
# There are 75 primes from 388001 to 389000
# There are 84 primes from 389001 to 390000
# There are 81 primes from 390001 to 391000
# There are 79 primes from 391001 to 392000
# There are 86 primes from 392001 to 393000
# There are 87 primes from 393001 to 394000
# There are 75 primes from 394001 to 395000
# There are 72 primes from 395001 to 396000
# There are 75 primes from 396001 to 397000
# There are 75 primes from 397001 to 398000
# There are 82 primes from 398001 to 399000
# There are 81 primes from 399001 to 400000
# The lowest number of primes from 1 to 5000000 is 67
# There are 70 primes from 400001 to 401000
# There are 71 primes from 401001 to 402000
# There are 76 primes from 402001 to 403000
# There are 75 primes from 403001 to 404000
# There are 70 primes from 404001 to 405000
# There are 83 primes from 405001 to 406000
# There are 67 primes from 406001 to 407000
# There are 81 primes from 407001 to 408000
# There are 79 primes from 408001 to 409000
# There are 82 primes from 409001 to 410000
# There are 73 primes from 410001 to 411000
# There are 81 primes from 411001 to 412000
# There are 74 primes from 412001 to 413000
# There are 69 primes from 413001 to 414000
# There are 90 primes from 414001 to 415000
# There are 80 primes from 415001 to 416000
# There are 67 primes from 416001 to 417000
# There are 82 primes from 417001 to 418000
# There are 85 primes from 418001 to 419000
# There are 75 primes from 419001 to 420000
# There are 75 primes from 420001 to 421000
# There are 73 primes from 421001 to 422000
# There are 77 primes from 422001 to 423000
# There are 83 primes from 423001 to 424000
# There are 81 primes from 424001 to 425000
# There are 74 primes from 425001 to 426000
# There are 71 primes from 426001 to 427000
# There are 78 primes from 427001 to 428000
# There are 71 primes from 428001 to 429000
# There are 89 primes from 429001 to 430000
# There are 76 primes from 430001 to 431000
# There are 79 primes from 431001 to 432000
# There are 84 primes from 432001 to 433000
# There are 80 primes from 433001 to 434000
# There are 85 primes from 434001 to 435000
# There are 82 primes from 435001 to 436000
# There are 73 primes from 436001 to 437000
# There are 70 primes from 437001 to 438000
# There are 75 primes from 438001 to 439000
# There are 75 primes from 439001 to 440000
# There are 79 primes from 440001 to 441000
# There are 72 primes from 441001 to 442000
# There are 85 primes from 442001 to 443000
# There are 88 primes from 443001 to 444000
# There are 82 primes from 444001 to 445000
# There are 68 primes from 445001 to 446000
# There are 68 primes from 446001 to 447000
# There are 73 primes from 447001 to 448000
# There are 70 primes from 448001 to 449000
# There are 80 primes from 449001 to 450000
# There are 92 primes from 450001 to 451000
# There are 76 primes from 451001 to 452000
# There are 63 primes from 452001 to 453000
# There are 72 primes from 453001 to 454000
# There are 74 primes from 454001 to 455000
# There are 82 primes from 455001 to 456000
# There are 73 primes from 456001 to 457000
# There are 77 primes from 457001 to 458000
# There are 75 primes from 458001 to 459000
# There are 68 primes from 459001 to 460000
# There are 77 primes from 460001 to 461000
# There are 69 primes from 461001 to 462000
# There are 74 primes from 462001 to 463000
# There are 77 primes from 463001 to 464000
# There are 85 primes from 464001 to 465000
# There are 74 primes from 465001 to 466000
# There are 69 primes from 466001 to 467000
# There are 83 primes from 467001 to 468000
# There are 85 primes from 468001 to 469000
# There are 72 primes from 469001 to 470000
# There are 87 primes from 470001 to 471000
# There are 78 primes from 471001 to 472000
# There are 73 primes from 472001 to 473000
# There are 78 primes from 473001 to 474000
# There are 80 primes from 474001 to 475000
# There are 86 primes from 475001 to 476000
# There are 75 primes from 476001 to 477000
# There are 69 primes from 477001 to 478000
# There are 85 primes from 478001 to 479000
# There are 71 primes from 479001 to 480000
# There are 77 primes from 480001 to 481000
# There are 78 primes from 481001 to 482000
# There are 82 primes from 482001 to 483000
# There are 75 primes from 483001 to 484000
# There are 65 primes from 484001 to 485000
# There are 63 primes from 485001 to 486000
# There are 82 primes from 486001 to 487000
# There are 78 primes from 487001 to 488000
# There are 83 primes from 488001 to 489000
# There are 78 primes from 489001 to 490000
# There are 78 primes from 490001 to 491000
# There are 76 primes from 491001 to 492000
# There are 67 primes from 492001 to 493000
# There are 82 primes from 493001 to 494000
# There are 80 primes from 494001 to 495000
# There are 87 primes from 495001 to 496000
# There are 68 primes from 496001 to 497000
# There are 81 primes from 497001 to 498000
# There are 72 primes from 498001 to 499000
# There are 81 primes from 499001 to 500000
# The lowest number of primes from 1 to 5000000 is 63
# There are 79 primes from 500001 to 501000
# There are 74 primes from 501001 to 502000
# There are 67 primes from 502001 to 503000
# There are 76 primes from 503001 to 504000
# There are 76 primes from 504001 to 505000
# There are 83 primes from 505001 to 506000
# There are 76 primes from 506001 to 507000
# There are 71 primes from 507001 to 508000
# There are 76 primes from 508001 to 509000
# There are 75 primes from 509001 to 510000
# There are 72 primes from 510001 to 511000
# There are 82 primes from 511001 to 512000
# There are 70 primes from 512001 to 513000
# There are 77 primes from 513001 to 514000
# There are 81 primes from 514001 to 515000
# There are 66 primes from 515001 to 516000
# There are 85 primes from 516001 to 517000
# There are 83 primes from 517001 to 518000
# There are 76 primes from 518001 to 519000
# There are 78 primes from 519001 to 520000
# There are 73 primes from 520001 to 521000
# There are 83 primes from 521001 to 522000
# There are 79 primes from 522001 to 523000
# There are 69 primes from 523001 to 524000
# There are 77 primes from 524001 to 525000
# There are 79 primes from 525001 to 526000
# There are 84 primes from 526001 to 527000
# There are 72 primes from 527001 to 528000
# There are 70 primes from 528001 to 529000
# There are 78 primes from 529001 to 530000
# There are 80 primes from 530001 to 531000
# There are 68 primes from 531001 to 532000
# There are 79 primes from 532001 to 533000
# There are 74 primes from 533001 to 534000
# There are 72 primes from 534001 to 535000
# There are 71 primes from 535001 to 536000
# There are 87 primes from 536001 to 537000
# There are 67 primes from 537001 to 538000
# There are 78 primes from 538001 to 539000
# There are 71 primes from 539001 to 540000
# There are 73 primes from 540001 to 541000
# There are 77 primes from 541001 to 542000
# There are 78 primes from 542001 to 543000
# There are 81 primes from 543001 to 544000
# There are 68 primes from 544001 to 545000
# There are 69 primes from 545001 to 546000
# There are 73 primes from 546001 to 547000
# There are 76 primes from 547001 to 548000
# There are 77 primes from 548001 to 549000
# There are 78 primes from 549001 to 550000
# There are 79 primes from 550001 to 551000
# There are 75 primes from 551001 to 552000
# There are 71 primes from 552001 to 553000
# There are 80 primes from 553001 to 554000
# There are 77 primes from 554001 to 555000
# There are 61 primes from 555001 to 556000
# There are 88 primes from 556001 to 557000
# There are 68 primes from 557001 to 558000
# There are 74 primes from 558001 to 559000
# There are 77 primes from 559001 to 560000
# There are 86 primes from 560001 to 561000
# There are 61 primes from 561001 to 562000
# There are 83 primes from 562001 to 563000
# There are 67 primes from 563001 to 564000
# There are 77 primes from 564001 to 565000
# There are 78 primes from 565001 to 566000
# There are 72 primes from 566001 to 567000
# There are 72 primes from 567001 to 568000
# There are 71 primes from 568001 to 569000
# There are 80 primes from 569001 to 570000
# There are 85 primes from 570001 to 571000
# There are 72 primes from 571001 to 572000
# There are 85 primes from 572001 to 573000
# There are 72 primes from 573001 to 574000
# There are 70 primes from 574001 to 575000
# There are 77 primes from 575001 to 576000
# There are 78 primes from 576001 to 577000
# There are 77 primes from 577001 to 578000
# There are 76 primes from 578001 to 579000
# There are 77 primes from 579001 to 580000
# There are 73 primes from 580001 to 581000
# There are 79 primes from 581001 to 582000
# There are 73 primes from 582001 to 583000
# There are 78 primes from 583001 to 584000
# There are 72 primes from 584001 to 585000
# There are 81 primes from 585001 to 586000
# There are 79 primes from 586001 to 587000
# There are 87 primes from 587001 to 588000
# There are 73 primes from 588001 to 589000
# There are 68 primes from 589001 to 590000
# There are 71 primes from 590001 to 591000
# There are 67 primes from 591001 to 592000
# There are 80 primes from 592001 to 593000
# There are 77 primes from 593001 to 594000
# There are 78 primes from 594001 to 595000
# There are 77 primes from 595001 to 596000
# There are 79 primes from 596001 to 597000
# There are 73 primes from 597001 to 598000
# There are 72 primes from 598001 to 599000
# There are 73 primes from 599001 to 600000
# The lowest number of primes from 1 to 5000000 is 61
# There are 76 primes from 600001 to 601000
# There are 73 primes from 601001 to 602000
# There are 83 primes from 602001 to 603000
# There are 76 primes from 603001 to 604000
# There are 73 primes from 604001 to 605000
# There are 74 primes from 605001 to 606000
# There are 72 primes from 606001 to 607000
# There are 78 primes from 607001 to 608000
# There are 78 primes from 608001 to 609000
# There are 80 primes from 609001 to 610000
# There are 73 primes from 610001 to 611000
# There are 71 primes from 611001 to 612000
# There are 76 primes from 612001 to 613000
# There are 79 primes from 613001 to 614000
# There are 71 primes from 614001 to 615000
# There are 75 primes from 615001 to 616000
# There are 85 primes from 616001 to 617000
# There are 81 primes from 617001 to 618000
# There are 67 primes from 618001 to 619000
# There are 73 primes from 619001 to 620000
# There are 77 primes from 620001 to 621000
# There are 70 primes from 621001 to 622000
# There are 74 primes from 622001 to 623000
# There are 75 primes from 623001 to 624000
# There are 78 primes from 624001 to 625000
# There are 69 primes from 625001 to 626000
# There are 70 primes from 626001 to 627000
# There are 70 primes from 627001 to 628000
# There are 71 primes from 628001 to 629000
# There are 75 primes from 629001 to 630000
# There are 67 primes from 630001 to 631000
# There are 81 primes from 631001 to 632000
# There are 77 primes from 632001 to 633000
# There are 70 primes from 633001 to 634000
# There are 82 primes from 634001 to 635000
# There are 78 primes from 635001 to 636000
# There are 73 primes from 636001 to 637000
# There are 74 primes from 637001 to 638000
# There are 59 primes from 638001 to 639000
# There are 72 primes from 639001 to 640000
# There are 77 primes from 640001 to 641000
# There are 71 primes from 641001 to 642000
# There are 68 primes from 642001 to 643000
# There are 70 primes from 643001 to 644000
# There are 86 primes from 644001 to 645000
# There are 75 primes from 645001 to 646000
# There are 74 primes from 646001 to 647000
# There are 79 primes from 647001 to 648000
# There are 73 primes from 648001 to 649000
# There are 84 primes from 649001 to 650000
# There are 61 primes from 650001 to 651000
# There are 74 primes from 651001 to 652000
# There are 85 primes from 652001 to 653000
# There are 69 primes from 653001 to 654000
# There are 78 primes from 654001 to 655000
# There are 73 primes from 655001 to 656000
# There are 71 primes from 656001 to 657000
# There are 70 primes from 657001 to 658000
# There are 79 primes from 658001 to 659000
# There are 73 primes from 659001 to 660000
# There are 83 primes from 660001 to 661000
# There are 70 primes from 661001 to 662000
# There are 74 primes from 662001 to 663000
# There are 77 primes from 663001 to 664000
# There are 77 primes from 664001 to 665000
# There are 77 primes from 665001 to 666000
# There are 73 primes from 666001 to 667000
# There are 74 primes from 667001 to 668000
# There are 66 primes from 668001 to 669000
# There are 74 primes from 669001 to 670000
# There are 75 primes from 670001 to 671000
# There are 76 primes from 671001 to 672000
# There are 76 primes from 672001 to 673000
# There are 77 primes from 673001 to 674000
# There are 73 primes from 674001 to 675000
# There are 75 primes from 675001 to 676000
# There are 74 primes from 676001 to 677000
# There are 63 primes from 677001 to 678000
# There are 82 primes from 678001 to 679000
# There are 83 primes from 679001 to 680000
# There are 75 primes from 680001 to 681000
# There are 78 primes from 681001 to 682000
# There are 66 primes from 682001 to 683000
# There are 78 primes from 683001 to 684000
# There are 72 primes from 684001 to 685000
# There are 74 primes from 685001 to 686000
# There are 74 primes from 686001 to 687000
# There are 82 primes from 687001 to 688000
# There are 74 primes from 688001 to 689000
# There are 79 primes from 689001 to 690000
# There are 60 primes from 690001 to 691000
# There are 79 primes from 691001 to 692000
# There are 77 primes from 692001 to 693000
# There are 73 primes from 693001 to 694000
# There are 76 primes from 694001 to 695000
# There are 77 primes from 695001 to 696000
# There are 73 primes from 696001 to 697000
# There are 79 primes from 697001 to 698000
# There are 62 primes from 698001 to 699000
# There are 72 primes from 699001 to 700000
# The lowest number of primes from 1 to 5000000 is 59
# There are 75 primes from 700001 to 701000
# There are 71 primes from 701001 to 702000
# There are 81 primes from 702001 to 703000
# There are 71 primes from 703001 to 704000
# There are 87 primes from 704001 to 705000
# There are 68 primes from 705001 to 706000
# There are 82 primes from 706001 to 707000
# There are 74 primes from 707001 to 708000
# There are 77 primes from 708001 to 709000
# There are 77 primes from 709001 to 710000
# There are 78 primes from 710001 to 711000
# There are 76 primes from 711001 to 712000
# There are 72 primes from 712001 to 713000
# There are 73 primes from 713001 to 714000
# There are 66 primes from 714001 to 715000
# There are 83 primes from 715001 to 716000
# There are 69 primes from 716001 to 717000
# There are 65 primes from 717001 to 718000
# There are 67 primes from 718001 to 719000
# There are 74 primes from 719001 to 720000
# There are 78 primes from 720001 to 721000
# There are 77 primes from 721001 to 722000
# There are 73 primes from 722001 to 723000
# There are 86 primes from 723001 to 724000
# There are 75 primes from 724001 to 725000
# There are 69 primes from 725001 to 726000
# There are 76 primes from 726001 to 727000
# There are 75 primes from 727001 to 728000
# There are 76 primes from 728001 to 729000
# There are 75 primes from 729001 to 730000
# There are 69 primes from 730001 to 731000
# There are 76 primes from 731001 to 732000
# There are 71 primes from 732001 to 733000
# There are 75 primes from 733001 to 734000
# There are 74 primes from 734001 to 735000
# There are 79 primes from 735001 to 736000
# There are 69 primes from 736001 to 737000
# There are 78 primes from 737001 to 738000
# There are 70 primes from 738001 to 739000
# There are 81 primes from 739001 to 740000
# There are 67 primes from 740001 to 741000
# There are 74 primes from 741001 to 742000
# There are 73 primes from 742001 to 743000
# There are 67 primes from 743001 to 744000
# There are 64 primes from 744001 to 745000
# There are 67 primes from 745001 to 746000
# There are 76 primes from 746001 to 747000
# There are 71 primes from 747001 to 748000
# There are 76 primes from 748001 to 749000
# There are 72 primes from 749001 to 750000
# There are 68 primes from 750001 to 751000
# There are 85 primes from 751001 to 752000
# There are 73 primes from 752001 to 753000
# There are 71 primes from 753001 to 754000
# There are 83 primes from 754001 to 755000
# There are 70 primes from 755001 to 756000
# There are 66 primes from 756001 to 757000
# There are 68 primes from 757001 to 758000
# There are 79 primes from 758001 to 759000
# There are 77 primes from 759001 to 760000
# There are 77 primes from 760001 to 761000
# There are 80 primes from 761001 to 762000
# There are 68 primes from 762001 to 763000
# There are 79 primes from 763001 to 764000
# There are 72 primes from 764001 to 765000
# There are 82 primes from 765001 to 766000
# There are 78 primes from 766001 to 767000
# There are 68 primes from 767001 to 768000
# There are 77 primes from 768001 to 769000
# There are 74 primes from 769001 to 770000
# There are 77 primes from 770001 to 771000
# There are 75 primes from 771001 to 772000
# There are 70 primes from 772001 to 773000
# There are 76 primes from 773001 to 774000
# There are 72 primes from 774001 to 775000
# There are 67 primes from 775001 to 776000
# There are 70 primes from 776001 to 777000
# There are 76 primes from 777001 to 778000
# There are 81 primes from 778001 to 779000
# There are 71 primes from 779001 to 780000
# There are 70 primes from 780001 to 781000
# There are 82 primes from 781001 to 782000
# There are 68 primes from 782001 to 783000
# There are 75 primes from 783001 to 784000
# There are 75 primes from 784001 to 785000
# There are 77 primes from 785001 to 786000
# There are 70 primes from 786001 to 787000
# There are 73 primes from 787001 to 788000
# There are 80 primes from 788001 to 789000
# There are 68 primes from 789001 to 790000
# There are 78 primes from 790001 to 791000
# There are 71 primes from 791001 to 792000
# There are 82 primes from 792001 to 793000
# There are 71 primes from 793001 to 794000
# There are 73 primes from 794001 to 795000
# There are 79 primes from 795001 to 796000
# There are 77 primes from 796001 to 797000
# There are 72 primes from 797001 to 798000
# There are 71 primes from 798001 to 799000
# There are 71 primes from 799001 to 800000
# The lowest number of primes from 1 to 5000000 is 59
# There are 85 primes from 800001 to 801000
# There are 66 primes from 801001 to 802000
# There are 70 primes from 802001 to 803000
# There are 69 primes from 803001 to 804000
# There are 78 primes from 804001 to 805000
# There are 79 primes from 805001 to 806000
# There are 68 primes from 806001 to 807000
# There are 70 primes from 807001 to 808000
# There are 69 primes from 808001 to 809000
# There are 78 primes from 809001 to 810000
# There are 78 primes from 810001 to 811000
# There are 72 primes from 811001 to 812000
# There are 69 primes from 812001 to 813000
# There are 72 primes from 813001 to 814000
# There are 78 primes from 814001 to 815000
# There are 69 primes from 815001 to 816000
# There are 75 primes from 816001 to 817000
# There are 75 primes from 817001 to 818000
# There are 62 primes from 818001 to 819000
# There are 83 primes from 819001 to 820000
# There are 75 primes from 820001 to 821000
# There are 72 primes from 821001 to 822000
# There are 84 primes from 822001 to 823000
# There are 78 primes from 823001 to 824000
# There are 71 primes from 824001 to 825000
# There are 81 primes from 825001 to 826000
# There are 78 primes from 826001 to 827000
# There are 69 primes from 827001 to 828000
# There are 69 primes from 828001 to 829000
# There are 68 primes from 829001 to 830000
# There are 76 primes from 830001 to 831000
# There are 79 primes from 831001 to 832000
# There are 82 primes from 832001 to 833000
# There are 68 primes from 833001 to 834000
# There are 67 primes from 834001 to 835000
# There are 73 primes from 835001 to 836000
# There are 71 primes from 836001 to 837000
# There are 64 primes from 837001 to 838000
# There are 80 primes from 838001 to 839000
# There are 69 primes from 839001 to 840000
# There are 70 primes from 840001 to 841000
# There are 69 primes from 841001 to 842000
# There are 83 primes from 842001 to 843000
# There are 68 primes from 843001 to 844000
# There are 78 primes from 844001 to 845000
# There are 70 primes from 845001 to 846000
# There are 69 primes from 846001 to 847000
# There are 77 primes from 847001 to 848000
# There are 75 primes from 848001 to 849000
# There are 68 primes from 849001 to 850000
# There are 70 primes from 850001 to 851000
# There are 77 primes from 851001 to 852000
# There are 74 primes from 852001 to 853000
# There are 66 primes from 853001 to 854000
# There are 71 primes from 854001 to 855000
# There are 73 primes from 855001 to 856000
# There are 78 primes from 856001 to 857000
# There are 76 primes from 857001 to 858000
# There are 69 primes from 858001 to 859000
# There are 71 primes from 859001 to 860000
# There are 77 primes from 860001 to 861000
# There are 74 primes from 861001 to 862000
# There are 83 primes from 862001 to 863000
# There are 60 primes from 863001 to 864000
# There are 80 primes from 864001 to 865000
# There are 80 primes from 865001 to 866000
# There are 68 primes from 866001 to 867000
# There are 78 primes from 867001 to 868000
# There are 80 primes from 868001 to 869000
# There are 73 primes from 869001 to 870000
# There are 79 primes from 870001 to 871000
# There are 58 primes from 871001 to 872000
# There are 76 primes from 872001 to 873000
# There are 65 primes from 873001 to 874000
# There are 75 primes from 874001 to 875000
# There are 80 primes from 875001 to 876000
# There are 75 primes from 876001 to 877000
# There are 67 primes from 877001 to 878000
# There are 78 primes from 878001 to 879000
# There are 75 primes from 879001 to 880000
# There are 80 primes from 880001 to 881000
# There are 69 primes from 881001 to 882000
# There are 72 primes from 882001 to 883000
# There are 73 primes from 883001 to 884000
# There are 69 primes from 884001 to 885000
# There are 77 primes from 885001 to 886000
# There are 76 primes from 886001 to 887000
# There are 71 primes from 887001 to 888000
# There are 77 primes from 888001 to 889000
# There are 68 primes from 889001 to 890000
# There are 68 primes from 890001 to 891000
# There are 80 primes from 891001 to 892000
# There are 69 primes from 892001 to 893000
# There are 72 primes from 893001 to 894000
# There are 74 primes from 894001 to 895000
# There are 80 primes from 895001 to 896000
# There are 64 primes from 896001 to 897000
# There are 75 primes from 897001 to 898000
# There are 76 primes from 898001 to 899000
# There are 61 primes from 899001 to 900000
# The lowest number of primes from 1 to 5000000 is 58
# There are 74 primes from 900001 to 901000
# There are 73 primes from 901001 to 902000
# There are 70 primes from 902001 to 903000
# There are 63 primes from 903001 to 904000
# There are 81 primes from 904001 to 905000
# There are 70 primes from 905001 to 906000
# There are 80 primes from 906001 to 907000
# There are 80 primes from 907001 to 908000
# There are 79 primes from 908001 to 909000
# There are 82 primes from 909001 to 910000
# There are 62 primes from 910001 to 911000
# There are 81 primes from 911001 to 912000
# There are 71 primes from 912001 to 913000
# There are 54 primes from 913001 to 914000
# There are 73 primes from 914001 to 915000
# There are 70 primes from 915001 to 916000
# There are 72 primes from 916001 to 917000
# There are 79 primes from 917001 to 918000
# There are 75 primes from 918001 to 919000
# There are 71 primes from 919001 to 920000
# There are 72 primes from 920001 to 921000
# There are 72 primes from 921001 to 922000
# There are 72 primes from 922001 to 923000
# There are 81 primes from 923001 to 924000
# There are 76 primes from 924001 to 925000
# There are 80 primes from 925001 to 926000
# There are 74 primes from 926001 to 927000
# There are 63 primes from 927001 to 928000
# There are 70 primes from 928001 to 929000
# There are 80 primes from 929001 to 930000
# There are 69 primes from 930001 to 931000
# There are 69 primes from 931001 to 932000
# There are 76 primes from 932001 to 933000
# There are 68 primes from 933001 to 934000
# There are 81 primes from 934001 to 935000
# There are 68 primes from 935001 to 936000
# There are 71 primes from 936001 to 937000
# There are 71 primes from 937001 to 938000
# There are 72 primes from 938001 to 939000
# There are 68 primes from 939001 to 940000
# There are 74 primes from 940001 to 941000
# There are 79 primes from 941001 to 942000
# There are 72 primes from 942001 to 943000
# There are 76 primes from 943001 to 944000
# There are 73 primes from 944001 to 945000
# There are 66 primes from 945001 to 946000
# There are 72 primes from 946001 to 947000
# There are 66 primes from 947001 to 948000
# There are 67 primes from 948001 to 949000
# There are 75 primes from 949001 to 950000
# There are 76 primes from 950001 to 951000
# There are 70 primes from 951001 to 952000
# There are 78 primes from 952001 to 953000
# There are 65 primes from 953001 to 954000
# There are 73 primes from 954001 to 955000
# There are 76 primes from 955001 to 956000
# There are 58 primes from 956001 to 957000
# There are 69 primes from 957001 to 958000
# There are 77 primes from 958001 to 959000
# There are 69 primes from 959001 to 960000
# There are 68 primes from 960001 to 961000
# There are 88 primes from 961001 to 962000
# There are 71 primes from 962001 to 963000
# There are 74 primes from 963001 to 964000
# There are 74 primes from 964001 to 965000
# There are 70 primes from 965001 to 966000
# There are 73 primes from 966001 to 967000
# There are 66 primes from 967001 to 968000
# There are 75 primes from 968001 to 969000
# There are 73 primes from 969001 to 970000
# There are 76 primes from 970001 to 971000
# There are 78 primes from 971001 to 972000
# There are 74 primes from 972001 to 973000
# There are 63 primes from 973001 to 974000
# There are 85 primes from 974001 to 975000
# There are 70 primes from 975001 to 976000
# There are 66 primes from 976001 to 977000
# There are 60 primes from 977001 to 978000
# There are 80 primes from 978001 to 979000
# There are 65 primes from 979001 to 980000
# There are 67 primes from 980001 to 981000
# There are 75 primes from 981001 to 982000
# There are 70 primes from 982001 to 983000
# There are 70 primes from 983001 to 984000
# There are 70 primes from 984001 to 985000
# There are 76 primes from 985001 to 986000
# There are 76 primes from 986001 to 987000
# There are 63 primes from 987001 to 988000
# There are 71 primes from 988001 to 989000
# There are 72 primes from 989001 to 990000
# There are 71 primes from 990001 to 991000
# There are 79 primes from 991001 to 992000
# There are 65 primes from 992001 to 993000
# There are 68 primes from 993001 to 994000
# There are 78 primes from 994001 to 995000
# There are 69 primes from 995001 to 996000
# There are 69 primes from 996001 to 997000
# There are 83 primes from 997001 to 998000
# There are 74 primes from 998001 to 999000
# There are 65 primes from 999001 to 1000000
# The lowest number of primes from 1 to 5000000 is 54
# There are 75 primes from 1000001 to 1001000
# There are 77 primes from 1001001 to 1002000
# There are 81 primes from 1002001 to 1003000
# There are 72 primes from 1003001 to 1004000
# There are 63 primes from 1004001 to 1005000
# There are 73 primes from 1005001 to 1006000
# There are 82 primes from 1006001 to 1007000
# There are 76 primes from 1007001 to 1008000
# There are 79 primes from 1008001 to 1009000
# There are 75 primes from 1009001 to 1010000
# There are 66 primes from 1010001 to 1011000
# There are 70 primes from 1011001 to 1012000
# There are 83 primes from 1012001 to 1013000
# There are 67 primes from 1013001 to 1014000
# There are 71 primes from 1014001 to 1015000
# There are 74 primes from 1015001 to 1016000
# There are 72 primes from 1016001 to 1017000
# There are 72 primes from 1017001 to 1018000
# There are 70 primes from 1018001 to 1019000
# There are 74 primes from 1019001 to 1020000
# There are 79 primes from 1020001 to 1021000
# There are 74 primes from 1021001 to 1022000
# There are 72 primes from 1022001 to 1023000
# There are 70 primes from 1023001 to 1024000
# There are 70 primes from 1024001 to 1025000
# There are 78 primes from 1025001 to 1026000
# There are 73 primes from 1026001 to 1027000
# There are 67 primes from 1027001 to 1028000
# There are 74 primes from 1028001 to 1029000
# There are 75 primes from 1029001 to 1030000
# There are 71 primes from 1030001 to 1031000
# There are 62 primes from 1031001 to 1032000
# There are 72 primes from 1032001 to 1033000
# There are 75 primes from 1033001 to 1034000
# There are 78 primes from 1034001 to 1035000
# There are 66 primes from 1035001 to 1036000
# There are 78 primes from 1036001 to 1037000
# There are 65 primes from 1037001 to 1038000
# There are 70 primes from 1038001 to 1039000
# There are 64 primes from 1039001 to 1040000
# There are 77 primes from 1040001 to 1041000
# There are 74 primes from 1041001 to 1042000
# There are 70 primes from 1042001 to 1043000
# There are 73 primes from 1043001 to 1044000
# There are 77 primes from 1044001 to 1045000
# There are 72 primes from 1045001 to 1046000
# There are 65 primes from 1046001 to 1047000
# There are 78 primes from 1047001 to 1048000
# There are 66 primes from 1048001 to 1049000
# There are 79 primes from 1049001 to 1050000
# There are 62 primes from 1050001 to 1051000
# There are 73 primes from 1051001 to 1052000
# There are 67 primes from 1052001 to 1053000
# There are 67 primes from 1053001 to 1054000
# There are 73 primes from 1054001 to 1055000
# There are 70 primes from 1055001 to 1056000
# There are 73 primes from 1056001 to 1057000
# There are 66 primes from 1057001 to 1058000
# There are 76 primes from 1058001 to 1059000
# There are 71 primes from 1059001 to 1060000
# There are 70 primes from 1060001 to 1061000
# There are 72 primes from 1061001 to 1062000
# There are 59 primes from 1062001 to 1063000
# There are 84 primes from 1063001 to 1064000
# There are 69 primes from 1064001 to 1065000
# There are 71 primes from 1065001 to 1066000
# There are 69 primes from 1066001 to 1067000
# There are 73 primes from 1067001 to 1068000
# There are 73 primes from 1068001 to 1069000
# There are 76 primes from 1069001 to 1070000
# There are 74 primes from 1070001 to 1071000
# There are 75 primes from 1071001 to 1072000
# There are 64 primes from 1072001 to 1073000
# There are 69 primes from 1073001 to 1074000
# There are 75 primes from 1074001 to 1075000
# There are 78 primes from 1075001 to 1076000
# There are 75 primes from 1076001 to 1077000
# There are 65 primes from 1077001 to 1078000
# There are 66 primes from 1078001 to 1079000
# There are 81 primes from 1079001 to 1080000
# There are 82 primes from 1080001 to 1081000
# There are 71 primes from 1081001 to 1082000
# There are 68 primes from 1082001 to 1083000
# There are 73 primes from 1083001 to 1084000
# There are 71 primes from 1084001 to 1085000
# There are 66 primes from 1085001 to 1086000
# There are 75 primes from 1086001 to 1087000
# There are 70 primes from 1087001 to 1088000
# There are 74 primes from 1088001 to 1089000
# There are 56 primes from 1089001 to 1090000
# There are 74 primes from 1090001 to 1091000
# There are 79 primes from 1091001 to 1092000
# There are 76 primes from 1092001 to 1093000
# There are 81 primes from 1093001 to 1094000
# There are 79 primes from 1094001 to 1095000
# There are 72 primes from 1095001 to 1096000
# There are 68 primes from 1096001 to 1097000
# There are 72 primes from 1097001 to 1098000
# There are 60 primes from 1098001 to 1099000
# There are 77 primes from 1099001 to 1100000
# The lowest number of primes from 1 to 5000000 is 54
# There are 73 primes from 1100001 to 1101000
# There are 71 primes from 1101001 to 1102000
# There are 78 primes from 1102001 to 1103000
# There are 68 primes from 1103001 to 1104000
# There are 77 primes from 1104001 to 1105000
# There are 76 primes from 1105001 to 1106000
# There are 75 primes from 1106001 to 1107000
# There are 67 primes from 1107001 to 1108000
# There are 83 primes from 1108001 to 1109000
# There are 68 primes from 1109001 to 1110000
# There are 76 primes from 1110001 to 1111000
# There are 74 primes from 1111001 to 1112000
# There are 81 primes from 1112001 to 1113000
# There are 68 primes from 1113001 to 1114000
# There are 72 primes from 1114001 to 1115000
# There are 74 primes from 1115001 to 1116000
# There are 62 primes from 1116001 to 1117000
# There are 79 primes from 1117001 to 1118000
# There are 72 primes from 1118001 to 1119000
# There are 58 primes from 1119001 to 1120000
# There are 82 primes from 1120001 to 1121000
# There are 65 primes from 1121001 to 1122000
# There are 64 primes from 1122001 to 1123000
# There are 75 primes from 1123001 to 1124000
# There are 67 primes from 1124001 to 1125000
# There are 73 primes from 1125001 to 1126000
# There are 67 primes from 1126001 to 1127000
# ...
# There are 59 primes from 4642001 to 4643000
# There are 66 primes from 4643001 to 4644000
# There are 56 primes from 4644001 to 4645000
# There are 66 primes from 4645001 to 4646000
# There are 71 primes from 4646001 to 4647000
# There are 73 primes from 4647001 to 4648000
# There are 59 primes from 4648001 to 4649000
# There are 73 primes from 4649001 to 4650000
# There are 58 primes from 4650001 to 4651000
# There are 72 primes from 4651001 to 4652000
# There are 53 primes from 4652001 to 4653000
# There are 62 primes from 4653001 to 4654000
# There are 64 primes from 4654001 to 4655000
# There are 62 primes from 4655001 to 4656000
# There are 52 primes from 4656001 to 4657000
# There are 71 primes from 4657001 to 4658000
# There are 63 primes from 4658001 to 4659000
# There are 59 primes from 4659001 to 4660000
# There are 70 primes from 4660001 to 4661000
# There are 64 primes from 4661001 to 4662000
# There are 63 primes from 4662001 to 4663000
# There are 72 primes from 4663001 to 4664000
# There are 69 primes from 4664001 to 4665000
# There are 59 primes from 4665001 to 4666000
# There are 62 primes from 4666001 to 4667000
# There are 68 primes from 4667001 to 4668000
# There are 74 primes from 4668001 to 4669000
# There are 64 primes from 4669001 to 4670000
# There are 65 primes from 4670001 to 4671000
# There are 66 primes from 4671001 to 4672000
# There are 63 primes from 4672001 to 4673000
# There are 67 primes from 4673001 to 4674000
# There are 63 primes from 4674001 to 4675000
# There are 76 primes from 4675001 to 4676000
# There are 62 primes from 4676001 to 4677000
# There are 65 primes from 4677001 to 4678000
# There are 60 primes from 4678001 to 4679000
# There are 79 primes from 4679001 to 4680000
# There are 64 primes from 4680001 to 4681000
# There are 69 primes from 4681001 to 4682000
# There are 67 primes from 4682001 to 4683000
# There are 71 primes from 4683001 to 4684000
# There are 59 primes from 4684001 to 4685000
# There are 76 primes from 4685001 to 4686000
# There are 65 primes from 4686001 to 4687000
# There are 74 primes from 4687001 to 4688000
# There are 63 primes from 4688001 to 4689000
# There are 59 primes from 4689001 to 4690000
# There are 60 primes from 4690001 to 4691000
# There are 59 primes from 4691001 to 4692000
# There are 63 primes from 4692001 to 4693000
# There are 66 primes from 4693001 to 4694000
# There are 65 primes from 4694001 to 4695000
# There are 71 primes from 4695001 to 4696000
# There are 75 primes from 4696001 to 4697000
# There are 69 primes from 4697001 to 4698000
# There are 61 primes from 4698001 to 4699000
# There are 55 primes from 4699001 to 4700000
# The lowest number of primes from 1 to 5000000 is 46
# There are 76 primes from 4700001 to 4701000
# There are 65 primes from 4701001 to 4702000
# There are 59 primes from 4702001 to 4703000
# There are 69 primes from 4703001 to 4704000
# There are 68 primes from 4704001 to 4705000
# There are 60 primes from 4705001 to 4706000
# There are 59 primes from 4706001 to 4707000
# There are 62 primes from 4707001 to 4708000
# There are 67 primes from 4708001 to 4709000
# There are 67 primes from 4709001 to 4710000
# There are 59 primes from 4710001 to 4711000
# There are 63 primes from 4711001 to 4712000
# There are 65 primes from 4712001 to 4713000
# There are 66 primes from 4713001 to 4714000
# There are 66 primes from 4714001 to 4715000
# There are 59 primes from 4715001 to 4716000
# There are 74 primes from 4716001 to 4717000
# There are 73 primes from 4717001 to 4718000
# There are 64 primes from 4718001 to 4719000
# There are 64 primes from 4719001 to 4720000
# There are 69 primes from 4720001 to 4721000
# There are 65 primes from 4721001 to 4722000
# There are 67 primes from 4722001 to 4723000
# There are 49 primes from 4723001 to 4724000
# There are 67 primes from 4724001 to 4725000
# There are 73 primes from 4725001 to 4726000
# There are 60 primes from 4726001 to 4727000
# There are 71 primes from 4727001 to 4728000
# There are 58 primes from 4728001 to 4729000
# There are 64 primes from 4729001 to 4730000
# There are 71 primes from 4730001 to 4731000
# There are 63 primes from 4731001 to 4732000
# There are 71 primes from 4732001 to 4733000
# There are 77 primes from 4733001 to 4734000
# There are 66 primes from 4734001 to 4735000
# There are 63 primes from 4735001 to 4736000
# There are 67 primes from 4736001 to 4737000
# There are 70 primes from 4737001 to 4738000
# There are 62 primes from 4738001 to 4739000
# There are 53 primes from 4739001 to 4740000
# There are 64 primes from 4740001 to 4741000
# There are 65 primes from 4741001 to 4742000
# There are 73 primes from 4742001 to 4743000
# There are 64 primes from 4743001 to 4744000
# There are 59 primes from 4744001 to 4745000
# There are 64 primes from 4745001 to 4746000
# There are 65 primes from 4746001 to 4747000
# There are 66 primes from 4747001 to 4748000
# There are 62 primes from 4748001 to 4749000
# There are 62 primes from 4749001 to 4750000
# There are 67 primes from 4750001 to 4751000
# There are 54 primes from 4751001 to 4752000
# There are 64 primes from 4752001 to 4753000
# There are 60 primes from 4753001 to 4754000
# There are 67 primes from 4754001 to 4755000
# There are 70 primes from 4755001 to 4756000
# There are 60 primes from 4756001 to 4757000
# There are 63 primes from 4757001 to 4758000
# There are 72 primes from 4758001 to 4759000
# There are 65 primes from 4759001 to 4760000
# There are 66 primes from 4760001 to 4761000
# There are 68 primes from 4761001 to 4762000
# There are 61 primes from 4762001 to 4763000
# There are 62 primes from 4763001 to 4764000
# There are 63 primes from 4764001 to 4765000
# There are 78 primes from 4765001 to 4766000
# There are 60 primes from 4766001 to 4767000
# There are 62 primes from 4767001 to 4768000
# There are 77 primes from 4768001 to 4769000
# There are 58 primes from 4769001 to 4770000
# There are 64 primes from 4770001 to 4771000
# There are 59 primes from 4771001 to 4772000
# There are 53 primes from 4772001 to 4773000
# There are 64 primes from 4773001 to 4774000
# There are 71 primes from 4774001 to 4775000
# There are 73 primes from 4775001 to 4776000
# There are 58 primes from 4776001 to 4777000
# There are 62 primes from 4777001 to 4778000
# There are 67 primes from 4778001 to 4779000
# There are 57 primes from 4779001 to 4780000
# There are 73 primes from 4780001 to 4781000
# There are 65 primes from 4781001 to 4782000
# There are 72 primes from 4782001 to 4783000
# There are 62 primes from 4783001 to 4784000
# There are 56 primes from 4784001 to 4785000
# There are 64 primes from 4785001 to 4786000
# There are 68 primes from 4786001 to 4787000
# There are 66 primes from 4787001 to 4788000
# There are 65 primes from 4788001 to 4789000
# There are 66 primes from 4789001 to 4790000
# There are 53 primes from 4790001 to 4791000
# There are 65 primes from 4791001 to 4792000
# There are 63 primes from 4792001 to 4793000
# There are 58 primes from 4793001 to 4794000
# There are 68 primes from 4794001 to 4795000
# There are 67 primes from 4795001 to 4796000
# There are 68 primes from 4796001 to 4797000
# There are 65 primes from 4797001 to 4798000
# There are 65 primes from 4798001 to 4799000
# There are 66 primes from 4799001 to 4800000
# The lowest number of primes from 1 to 5000000 is 46
# There are 65 primes from 4800001 to 4801000
# There are 64 primes from 4801001 to 4802000
# There are 70 primes from 4802001 to 4803000
# There are 78 primes from 4803001 to 4804000
# There are 67 primes from 4804001 to 4805000
# There are 59 primes from 4805001 to 4806000
# There are 70 primes from 4806001 to 4807000
# There are 60 primes from 4807001 to 4808000
# There are 66 primes from 4808001 to 4809000
# There are 58 primes from 4809001 to 4810000
# There are 64 primes from 4810001 to 4811000
# There are 60 primes from 4811001 to 4812000
# There are 68 primes from 4812001 to 4813000
# There are 70 primes from 4813001 to 4814000
# There are 58 primes from 4814001 to 4815000
# There are 62 primes from 4815001 to 4816000
# There are 67 primes from 4816001 to 4817000
# There are 72 primes from 4817001 to 4818000
# There are 64 primes from 4818001 to 4819000
# There are 70 primes from 4819001 to 4820000
# There are 60 primes from 4820001 to 4821000
# There are 67 primes from 4821001 to 4822000
# There are 73 primes from 4822001 to 4823000
# There are 61 primes from 4823001 to 4824000
# There are 63 primes from 4824001 to 4825000
# There are 58 primes from 4825001 to 4826000
# There are 53 primes from 4826001 to 4827000
# There are 68 primes from 4827001 to 4828000
# There are 64 primes from 4828001 to 4829000
# There are 64 primes from 4829001 to 4830000
# There are 62 primes from 4830001 to 4831000
# There are 61 primes from 4831001 to 4832000
# There are 75 primes from 4832001 to 4833000
# There are 60 primes from 4833001 to 4834000
# There are 66 primes from 4834001 to 4835000
# There are 84 primes from 4835001 to 4836000
# There are 67 primes from 4836001 to 4837000
# There are 76 primes from 4837001 to 4838000
# There are 68 primes from 4838001 to 4839000
# There are 59 primes from 4839001 to 4840000
# There are 62 primes from 4840001 to 4841000
# There are 61 primes from 4841001 to 4842000
# There are 63 primes from 4842001 to 4843000
# There are 58 primes from 4843001 to 4844000
# There are 66 primes from 4844001 to 4845000
# There are 59 primes from 4845001 to 4846000
# There are 65 primes from 4846001 to 4847000
# There are 70 primes from 4847001 to 4848000
# There are 67 primes from 4848001 to 4849000
# There are 63 primes from 4849001 to 4850000
# There are 67 primes from 4850001 to 4851000
# There are 70 primes from 4851001 to 4852000
# There are 70 primes from 4852001 to 4853000
# There are 56 primes from 4853001 to 4854000
# There are 69 primes from 4854001 to 4855000
# There are 57 primes from 4855001 to 4856000
# There are 62 primes from 4856001 to 4857000
# There are 62 primes from 4857001 to 4858000
# There are 71 primes from 4858001 to 4859000
# There are 61 primes from 4859001 to 4860000
# There are 75 primes from 4860001 to 4861000
# There are 62 primes from 4861001 to 4862000
# There are 54 primes from 4862001 to 4863000
# There are 73 primes from 4863001 to 4864000
# There are 67 primes from 4864001 to 4865000
# There are 65 primes from 4865001 to 4866000
# There are 75 primes from 4866001 to 4867000
# There are 68 primes from 4867001 to 4868000
# There are 67 primes from 4868001 to 4869000
# There are 63 primes from 4869001 to 4870000
# There are 60 primes from 4870001 to 4871000
# There are 74 primes from 4871001 to 4872000
# There are 62 primes from 4872001 to 4873000
# There are 61 primes from 4873001 to 4874000
# There are 58 primes from 4874001 to 4875000
# There are 66 primes from 4875001 to 4876000
# There are 60 primes from 4876001 to 4877000
# There are 66 primes from 4877001 to 4878000
# There are 62 primes from 4878001 to 4879000
# There are 67 primes from 4879001 to 4880000
# There are 69 primes from 4880001 to 4881000
# There are 73 primes from 4881001 to 4882000
# There are 65 primes from 4882001 to 4883000
# There are 60 primes from 4883001 to 4884000
# There are 69 primes from 4884001 to 4885000
# There are 64 primes from 4885001 to 4886000
# There are 69 primes from 4886001 to 4887000
# There are 66 primes from 4887001 to 4888000
# There are 70 primes from 4888001 to 4889000
# There are 64 primes from 4889001 to 4890000
# There are 77 primes from 4890001 to 4891000
# There are 65 primes from 4891001 to 4892000
# There are 59 primes from 4892001 to 4893000
# There are 78 primes from 4893001 to 4894000
# There are 63 primes from 4894001 to 4895000
# There are 67 primes from 4895001 to 4896000
# There are 69 primes from 4896001 to 4897000
# There are 68 primes from 4897001 to 4898000
# There are 61 primes from 4898001 to 4899000
# There are 72 primes from 4899001 to 4900000
# The lowest number of primes from 1 to 5000000 is 46
# There are 75 primes from 4900001 to 4901000
# There are 72 primes from 4901001 to 4902000
# There are 61 primes from 4902001 to 4903000
# There are 56 primes from 4903001 to 4904000
# There are 59 primes from 4904001 to 4905000
# There are 60 primes from 4905001 to 4906000
# There are 73 primes from 4906001 to 4907000
# There are 68 primes from 4907001 to 4908000
# There are 73 primes from 4908001 to 4909000
# There are 54 primes from 4909001 to 4910000
# There are 58 primes from 4910001 to 4911000
# There are 69 primes from 4911001 to 4912000
# There are 63 primes from 4912001 to 4913000
# There are 61 primes from 4913001 to 4914000
# There are 70 primes from 4914001 to 4915000
# There are 59 primes from 4915001 to 4916000
# There are 65 primes from 4916001 to 4917000
# There are 52 primes from 4917001 to 4918000
# There are 71 primes from 4918001 to 4919000
# There are 66 primes from 4919001 to 4920000
# There are 66 primes from 4920001 to 4921000
# There are 71 primes from 4921001 to 4922000
# There are 65 primes from 4922001 to 4923000
# There are 68 primes from 4923001 to 4924000
# There are 65 primes from 4924001 to 4925000
# There are 60 primes from 4925001 to 4926000
# There are 65 primes from 4926001 to 4927000
# There are 67 primes from 4927001 to 4928000
# There are 68 primes from 4928001 to 4929000
# There are 58 primes from 4929001 to 4930000
# There are 72 primes from 4930001 to 4931000
# There are 59 primes from 4931001 to 4932000
# There are 68 primes from 4932001 to 4933000
# There are 62 primes from 4933001 to 4934000
# There are 63 primes from 4934001 to 4935000
# There are 72 primes from 4935001 to 4936000
# There are 63 primes from 4936001 to 4937000
# There are 58 primes from 4937001 to 4938000
# There are 70 primes from 4938001 to 4939000
# There are 68 primes from 4939001 to 4940000
# There are 63 primes from 4940001 to 4941000
# There are 66 primes from 4941001 to 4942000
# There are 54 primes from 4942001 to 4943000
# There are 69 primes from 4943001 to 4944000
# There are 76 primes from 4944001 to 4945000
# There are 65 primes from 4945001 to 4946000
# There are 72 primes from 4946001 to 4947000
# There are 58 primes from 4947001 to 4948000
# There are 58 primes from 4948001 to 4949000
# There are 69 primes from 4949001 to 4950000
# There are 65 primes from 4950001 to 4951000
# There are 65 primes from 4951001 to 4952000
# There are 69 primes from 4952001 to 4953000
# There are 66 primes from 4953001 to 4954000
# There are 64 primes from 4954001 to 4955000
# There are 69 primes from 4955001 to 4956000
# There are 63 primes from 4956001 to 4957000
# There are 74 primes from 4957001 to 4958000
# There are 51 primes from 4958001 to 4959000
# There are 54 primes from 4959001 to 4960000
# There are 74 primes from 4960001 to 4961000
# There are 72 primes from 4961001 to 4962000
# There are 68 primes from 4962001 to 4963000
# There are 66 primes from 4963001 to 4964000
# There are 65 primes from 4964001 to 4965000
# There are 81 primes from 4965001 to 4966000
# There are 57 primes from 4966001 to 4967000
# There are 72 primes from 4967001 to 4968000
# There are 66 primes from 4968001 to 4969000
# There are 62 primes from 4969001 to 4970000
# There are 55 primes from 4970001 to 4971000
# There are 62 primes from 4971001 to 4972000
# There are 69 primes from 4972001 to 4973000
# There are 56 primes from 4973001 to 4974000
# There are 62 primes from 4974001 to 4975000
# There are 76 primes from 4975001 to 4976000
# There are 69 primes from 4976001 to 4977000
# There are 73 primes from 4977001 to 4978000
# There are 65 primes from 4978001 to 4979000
# There are 74 primes from 4979001 to 4980000
# There are 56 primes from 4980001 to 4981000
# There are 59 primes from 4981001 to 4982000
# There are 60 primes from 4982001 to 4983000
# There are 70 primes from 4983001 to 4984000
# There are 69 primes from 4984001 to 4985000
# There are 64 primes from 4985001 to 4986000
# There are 76 primes from 4986001 to 4987000
# There are 67 primes from 4987001 to 4988000
# There are 62 primes from 4988001 to 4989000
# There are 70 primes from 4989001 to 4990000
# There are 67 primes from 4990001 to 4991000
# There are 73 primes from 4991001 to 4992000
# There are 64 primes from 4992001 to 4993000
# There are 66 primes from 4993001 to 4994000
# There are 52 primes from 4994001 to 4995000
# There are 67 primes from 4995001 to 4996000
# There are 57 primes from 4996001 to 4997000
# There are 57 primes from 4997001 to 4998000
# There are 67 primes from 4998001 to 4999000
# There are 71 primes from 4999001 to 5000000
# The lowest number of primes from 1 to 5000000 is 46
# There are 348513 primes up to 5000000

# %% [markdown]
# As you can see from the graph we bottom out from 3,279,001 to 3,280,000 with 46 primes per thousand.

# %% [markdown]
# Finally, I went up to 50 Million (the output is too long to share but here's the plot').
# I ran it in  <A HREF="https://github.com/spyder-ide">Spyder</A>:

# %%
from IPython.display import Image
Image(filename="50m_primes_2.png")

# %% [markdown]
# The lowest number of primes per thouand? 36.

# %% [markdown]
# Here's a link to a great short video on the topic: https://www.youtube.com/watch?v=7jzCJJIc59E. <p>
# It goes into the prime spiral and other things.

# %%
# %load num_primes3.py
#!/usr/bin/python3

from  other_prime_func import isprime
import matplotlib.pylab as plt

start_num=1
end_num=50000000

start_batch=start_num
increment_mon=999
next_batch=start_batch+increment_mon

checkpoint1=1000
checkpoint2=100000

counter=0
howmany_per_thous=[]
all_primes_list=[]

number=start_num
while number <= end_num:
	isitprime=isprime(number)
	if isitprime:
		all_primes_list.append(number)
		counter+=1
	if number %  checkpoint1 == 0 and number > start_num:
		print ("There are",counter,"primes from",start_batch,"to",next_batch)
		howmany_per_thous.append(counter)
		counter=0
		start_batch+=checkpoint1
		next_batch+=checkpoint1
	if number %  checkpoint2 == 0 and number > start_num:
		print ("The lowest number of primes from",start_num,"to",end_num,"is",\
	min(howmany_per_thous))
	number+=1

print ("There are",len(all_primes_list),"primes up to",end_num)

thousands=list(range(start_num+increment_mon,end_num+1,checkpoint1))
plt.scatter(thousands,howmany_per_thous,s=40)
plt.title("Number of Primes per 1000")
plt.xlabel("Thousands")
plt.ylabel("Number of Primes")
plt.axis([start_num, end_num, 0, 200])
plt.show()

# %% [markdown]
# Here's the supporting Code. With embedded credit to SO. I wrote my own code from a naive standpoint and just trying some fun things. It was a bit slower than I wanted.

# %%
# %load other_prime_func.py
#!/usr/bin/python3

"""
Very fast prime number determiner... 

https://stackoverflow.com/questions/1801391/what-is-the-best-algorithm-for-checking-if-a-number-is-prime
    
"""
def isprime(n):
    if n == 1:
        return False
    if n == 2:
        return True
    if n == 3:
        return True
    if n % 2 == 0:
        return False
    if n % 3 == 0:
        return False

    i = 5
    w = 2

    while i * i <= n:
        if n % i == 0:
            return False

        i += w
        w = 6 - w

    return True

# %% [markdown]
# Finally, kudos to showing how to export an externally embedded file from a Jupyter Notebook: https://stackoverflow.com/questions/26068316/embedding-image-in-ipython-notebook-for-distribution
